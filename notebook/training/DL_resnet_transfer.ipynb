# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import Dataset,DataLoader

from tqdm.notebook import tqdm

SR = 22050
DURATION = 30

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("kgg_key")
secret_value_1 = user_secrets.get_secret("kgg_user")
secret_value_2 = user_secrets.get_secret("WANDB_API_KEY")


#============ Check for GPU availability ==============================#
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"🚀 Using device: {device}")

RANDOM_SEED = 42
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
if torch.cuda.is_available():
    print("GPU is available.Setting RANDOM_SEED .... ")
        # setting for both CPU and GPU
    torch.cuda.manual_seed_all(RANDOM_SEED)
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
else:
    print("   Running on CPU")
print("\n✅ Environment setup complete!")

import warnings
warnings.filterwarnings("ignore")
# Out:
# 🚀 Using device: cuda
# GPU is available.Setting RANDOM_SEED ....
#    GPU: Tesla T4
#    Memory: 14.6 GB
#
# ✅ Environment setup complete!

# %% [markdown]
# First Neural Network & CNNs!
#
# * Learn PyTorch basics: Tensors, Dataset (custom loader for training), DataLoader.
# * Convert audio to 2D/1D Mel-Spectrograms.
# * Build a simple CNN (Convolutional Neural Network)/NN (Neural Network) to process the spectrograms.
# * Implement training loop, loss, optimizer, and wandb logging.
# * Train and evaluate your CNN/NN (Neural Network)model.

# %% [markdown]
# # Definition

# %% [markdown]
# ## - Utility

# %%
def extract_paths(pc=15000,test_size=0.2):
    GENRES = ['blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock'] 
    train_paths = []
    val_paths = []
    count = 0
    tr_count = 0
    val_count = 0
    
    paths_count = pc
    test_size = paths_count*test_size
    train_size = paths_count - test_size
    
    for g in GENRES:
        root_dir_path = f"/kaggle/input/datasets/akashkumbhakar/{g}-mel-15000"
        for i in range(0,paths_count):
            file_name = f"mashup_{i}.wav.npy"
            path = os.path.join(root_dir_path,file_name)
            if i >= train_size:
                val_paths.append((path,g))
                val_count += 1
            else : 
                train_paths.append((path,g))
                tr_count += 1
            count += 1
    print("Total paths (music files) : ", count)
    print("Total training files : ", tr_count)
    print("Total validation files : ", val_count)
    return train_paths,val_paths

def check_split():
    GENRES = ['blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock'] 
    g_c = {}
    for i in tr:
        if i[1] in g_c.keys():
            g_c[i[1]] += 1
        else:
            g_c[i[1]] = 1
    return g_c

def genre_to_idx(str_label):
    genre_to_id = {'blues':0, 'classical':1, 'country':2, 'disco':3, 'hiphop':4,'jazz':5, 'metal':6, 'pop':7, 'reggae':8, 'rock':9}
    y = genre_to_id[str_label]

    return y

def idx_to_genre(targets):
    id_to_genre = {0:'blues', 1:'classical', 2:'country', 3:'disco', 4:'hiphop',5:'jazz', 6:'metal', 7:'pop', 8:'reggae', 9:'rock'}
    y = [id_to_genre[id] for id in targets]

    return y

# %% [markdown]
# ## - Dataset and DataLoader

# %%
class MelDataset(Dataset):
    def __init__(self,paths,transform):  # paths : List[(path,label)]
        self.paths = paths
        self.transform = transform
    def __len__(self):
        return len(self.paths)
    def __getitem__(self,idx):
        mel = np.load(self.paths[idx][0])
        label = genre_to_idx(self.paths[idx][1])
        #mel = torch.from_numpy(mel).float()
        mel = self.transform(mel)
        label = torch.tensor(label, dtype=torch.long)
        return mel,label

data_transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[-45.60], std=[16.60])
])

# %% [markdown]
# ## - Coonfig

# %%
config = {
    "model_name" : "resnet-transfer",
    "version" : 'v1',
    "batch_size" : 64,
    "lr" : 0.0001,
    "sample_count" : 0,
    "epochs" : 20,
    "log_wandb" : False,
    "description" : None
}

try:
    dir_path = f"/kaggle/working/{config['model_name']}"
    os.makedirs(dir_path, exist_ok=True)
    print(f"Directory created at: {dir_path}")
except Exception as e:
    print(f"Error creating directory: {e}")
# Out:
# Directory created at: /kaggle/working/resnet-transfer

# %%
train_paths,val_paths = extract_paths(pc=15000)

train_dataset = MelDataset(train_paths,data_transformer)
train_loader = DataLoader(
    train_dataset,
    batch_size=config['batch_size'],
    shuffle=True,
    num_workers=4,
    persistent_workers=True,
    pin_memory=True
)
val_dataset = MelDataset(val_paths,data_transformer)
val_loader = DataLoader(
    val_dataset,
    batch_size=config['batch_size'],
    shuffle=True,
    num_workers=4,
    persistent_workers=True,
    pin_memory=True
)
config['sample_count'] = len(train_paths)
print(f"✅ BATCH SIZE : {config['batch_size']} | Size of Train Dataloader : {len(train_loader)}  |  Size of Val Dataloader : {len(val_loader)}")
# Out:
# Total paths (music files) :  150000
# Total training files :  120000
# Total validation files :  30000
# ✅ BATCH SIZE : 64 | Size of Train Dataloader : 1875  |  Size of Val Dataloader : 469

# %% [markdown]
# ## - Model

# %% [markdown]
# #### -- loading resnet model

# %%
from torchvision.models import resnet18,ResNet18_Weights
res_net = resnet18(weights=ResNet18_Weights.DEFAULT, progress=False)
res_net
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
class MelResNet18(nn.Module):
    def __init__(self,res_net,num_class):
        super().__init__()
        # reshapeing pretrained weights to channel=1
        #old_weights = res_net.conv1.weight
        #res_net.conv1.weight.data = old_weights.mean(dim=1, keepdim=True)
        
        res_net.conv1 = nn.Conv2d(1,64,kernel_size=(3, 3), stride=2, padding=3, bias=False)
        for param in res_net.parameters():
            param.requires_grad = False

        res_net.fc = nn.Linear(res_net.fc.in_features,num_class)
        self.resnet = res_net
        
    def forward(self, x):
        x = self.resnet(x)
        return x

model = MelResNet18(res_net,10)
grad_param_count = 0
total_pram_count = 0
for name,p in model.named_parameters():
    mark = ""
    total_pram_count += p.numel()
    if p.requires_grad:
        mark = "[RG]" # [RG] for gradient computation
        grad_param_count += p.numel()
    print(mark," ",name," - ",p.size()," - ",p.numel())

print(f"\nTotal Parameter : {total_pram_count}\nParameters with Gradient : {grad_param_count}")
# Out:
#    resnet.conv1.weight  -  torch.Size([64, 1, 7, 7])  -  3136
#    resnet.bn1.weight  -  torch.Size([64])  -  64
#    resnet.bn1.bias  -  torch.Size([64])  -  64
#    resnet.layer1.0.conv1.weight  -  torch.Size([64, 64, 3, 3])  -  36864
#    resnet.layer1.0.bn1.weight  -  torch.Size([64])  -  64
#    resnet.layer1.0.bn1.bias  -  torch.Size([64])  -  64
#    resnet.layer1.0.conv2.weight  -  torch.Size([64, 64, 3, 3])  -  36864
#    resnet.layer1.0.bn2.weight  -  torch.Size([64])  -  64
#    resnet.layer1.0.bn2.bias  -  torch.Size([64])  -  64
#    resnet.layer1.1.conv1.weight  -  torch.Size([64, 64, 3, 3])  -  36864
#    resnet.layer1.1.bn1.weight  -  torch.Size([64])  -  64
#    resnet.layer1.1.bn1.bias  -  torch.Size([64])  -  64
#    resnet.layer1.1.conv2.weight  -  torch.Size([64, 64, 3, 3])  -  36864
#    resnet.layer1.1.bn2.weight  -  torch.Size([64])  -  64
#    resnet.layer1.1.bn2.bias  -  torch.Size([64])  -  64
#    resnet.layer2.0.conv1.weight  -  torch.Size([128, 64, 3, 3])  -  73728
#    resnet.layer2.0.bn1.weight  -  torch.Size([128])  -  128
#    resnet.layer2.0.bn1.bias  -  torch.Size([128])  -  128
#    resnet.layer2.0.conv2.weight  -  torch.Size([128, 128, 3, 3])  -  147456
#    resnet.layer2.0.bn2.weight  -  torch.Size([128])  -  128
#    resnet.layer2.0.bn2.bias  -  torch.Size([128])  -  128
#    resnet.layer2.0.downsample.0.weight  -  torch.Size([128, 64, 1, 1])  -  8192
#    resnet.layer2.0.downsample.1.weight  -  torch.Size([128])  -  128
#    resnet.layer2.0.downsample.1.bias  -  torch.Size([128])  -  128
#    resnet.layer2.1.conv1.weight  -  torch.Size([128, 128, 3, 3])  -  147456
#    resnet.layer2.1.bn1.weight  -  torch.Size([128])  -  128
#    resnet.layer2.1.bn1.bias  -  torch.Size([128])  -  128
#    resnet.layer2.1.conv2.weight  -  torch.Size([128, 128, 3, 3])  -  147456
#    resnet.layer2.1.bn2.weight  -  torch.Size([128])  -  128
#    resnet.layer2.1.bn2.bias  -  torch.Size([128])  -  128
#    resnet.layer3.0.conv1.weight  -  torch.Size([256, 128, 3, 3])  -  294912
#    resnet.layer3.0.bn1.weight  -  torch.Size([256])  -  256
#    resnet.layer3.0.bn1.bias  -  torch.Size([256])  -  256
#    resnet.layer3.0.conv2.weight  -  torch.Size([256, 256, 3, 3])  -  589824
#    resnet.layer3.0.bn2.weight  -  torch.Size([256])  -  256
#    resnet.layer3.0.bn2.bias  -  torch.Size([256])  -  256
#    resnet.layer3.0.downsample.0.weight  -  torch.Size([256, 128, 1, 1])  -  32768
#    resnet.layer3.0.downsample.1.weight  -  torch.Size([256])  -  256
#    resnet.layer3.0.downsample.1.bias  -  torch.Size([256])  -  256
#    resnet.layer3.1.conv1.weight  -  torch.Size([256, 256, 3, 3])  -  589824
#    resnet.layer3.1.bn1.weight  -  torch.Size([256])  -  256
#    resnet.layer3.1.bn1.bias  -  torch.Size([256])  -  256
#    resnet.layer3.1.conv2.weight  -  torch.Size([256, 256, 3, 3])  -  589824
#    resnet.layer3.1.bn2.weight  -  torch.Size([256])  -  256
#    resnet.layer3.1.bn2.bias  -  torch.Size([256])  -  256
#    resnet.layer4.0.conv1.weight  -  torch.Size([512, 256, 3, 3])  -  1179648
#    resnet.layer4.0.bn1.weight  -  torch.Size([512])  -  512
#    resnet.layer4.0.bn1.bias  -  torch.Size([512])  -  512
#    resnet.layer4.0.conv2.weight  -  torch.Size([512, 512, 3, 3])  -  2359296
#    resnet.layer4.0.bn2.weight  -  torch.Size([512])  -  512
#    resnet.layer4.0.bn2.bias  -  torch.Size([512])  -  512
#    resnet.layer4.0.downsample.0.weight  -  torch.Size([512, 256, 1, 1])  -  131072
#    resnet.layer4.0.downsample.1.weight  -  torch.Size([512])  -  512
#    resnet.layer4.0.downsample.1.bias  -  torch.Size([512])  -  512
#    resnet.layer4.1.conv1.weight  -  torch.Size([512, 512, 3, 3])  -  2359296
#    resnet.layer4.1.bn1.weight  -  torch.Size([512])  -  512
#    resnet.layer4.1.bn1.bias  -  torch.Size([512])  -  512
#    resnet.layer4.1.conv2.weight  -  torch.Size([512, 512, 3, 3])  -  2359296
#    resnet.layer4.1.bn2.weight  -  torch.Size([512])  -  512
#    resnet.layer4.1.bn2.bias  -  torch.Size([512])  -  512
# [RG]   resnet.fc.weight  -  torch.Size([10, 512])  -  5120
# [RG]   resnet.fc.bias  -  torch.Size([10])  -  10
#
# Total Parameter : 11175370
# Parameters with Gradient : 5130

# %% [markdown]
# ## - Training

# %%
def train(model,train_loader,val_loader,loss_fn, optimizer,config):
    train_loss = []
    train_f1_score = []
    max_f1 = 0.0
    best_model_state = None
    best_optim_state = None
    best_train_loss = None
    best_val_loss = None
    model.train()

    # initialization of wandb
    log_wandb = config["log_wandb"]
    run = None
    if log_wandb:
        run = wandb.init(
            entity="23f1001065-indian-institute-of-technology-madras",
            project="23f1001065-t12026",
            name=config['run_name'],
            config = config
        )
    num_epochs = config['epochs']
    for epoch in range(num_epochs):
        running_loss = 0.0
        progress_bar = tqdm(enumerate(train_loader), total=len(train_loader),desc=f"Epoch {epoch+1}/{num_epochs}")
        for i,(mels,labels) in progress_bar:
            mels , labels = mels.to(device,non_blocking=True), labels.to(device,non_blocking=True)
            optimizer.zero_grad()
            
            outputs = model(mels)
            loss = loss_fn(outputs, labels)
        
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            avg_loss = running_loss / (i + 1)

            progress_bar.set_postfix({
                'loss': f"{avg_loss:.4f}"
            })
        loss = running_loss / len(train_loader)
        t,p,f1score,val_loss = validation(model,val_loader,criterion)
        print(f"Train Loss: {loss:.4f}")
        # Upload metrics
        if run:
            run.log({
                "train_loss" : float(loss),
                "val_loss" : float(val_loss),
                "f1_score" : float(f1score)
            })
        if f1score > max_f1 + 0.001 :
            max_f1 = f1score
            best_train_loss = loss
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            best_optim_state = optimizer.state_dict()
    # Close Wandb
    if run:
        run.finish()
    return (best_model_state,
            best_optim_state,
            best_train_loss,
            best_val_loss,
            max_f1)

# %% [markdown]
# ## - Evaluation

# %%
def validation(model,val_loader,loss_fn):
    model.eval()
    val_loss = 0.0
    all_true = []
    all_pred = []
    with torch.no_grad():
        progress_bar = tqdm(enumerate(val_loader), total=len(val_loader),desc=f"Validation")
        for i,(mels,labels) in progress_bar:
            mels,labels = mels.to(device,non_blocking=True),labels.to(device,non_blocking=True)
            output = model(mels)
            loss = loss_fn(output,labels)

            probs = torch.softmax(output,dim=1) 
            predicted_y = torch.argmax(probs,dim=1)
            
            val_loss += loss.item()
            avg_loss = val_loss / (i + 1)

            progress_bar.set_postfix({
                'loss': f"{avg_loss:.4f}"
            })

            all_true.extend(labels.cpu().numpy())
            all_pred.extend(predicted_y.cpu().numpy())
        #all_true = torch.cat(all_true,dim=0)
        #all_pred = torch.cat(all_pred,dim=0).cpu().numpy()
        print(len(all_true),len(all_pred))
    
        loss = val_loss/len(val_loader)
        f1score = f1_score(all_true,all_pred,average='macro')

        print(f"Validation Loss : {loss},  F1_score : {f1score}")
        return all_true,all_pred,f1score,loss

# %% [markdown]
# # Wandb login

# %%
while True:
    choice = input("Dou you want to log at WanDb[YES/NO] ?")
    if choice in ['YES','NO']:
        break
    else:
        print("Invalid input : Please enter 'YES' or 'NO'.")
if choice == 'YES':
    config["log_wandb"] = True
    print("Continuing....")
    import wandb
    print(f"Wandb version: {wandb.__version__}")
    wandb.login(key=secret_value_2)
else:
    config["log_wandb"] = False
    print("Aborting.")
# Out:
# Dou you want to log at WanDb[YES/NO] ? YES
# Continuing....
# Wandb version: 0.24.0
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: 23f1001065 (23f1001065-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Training

# %% [markdown]
# ## - Setup

# %%
model = MelResNet18(res_net,10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'])

# %% [markdown]
# ## - Training loop execution

# %%
run_name = "-".join([str(attribute) for attribute in list(config.values())[:6]])
config['run_name'] = run_name
print(run_name)
best_model_state,best_optim_state,train_loss,val_loss,f1 = train(model,train_loader,val_loader,criterion, optimizer,config)
# Out:
# resnet-transfer-v1-64-0.0001-1875-20
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260313_063856-g1yh560v</code>
# Syncing run <strong><a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026/runs/g1yh560v' target="_blank">resnet-transfer-v1-64-0.0001-1875-20</a></strong> to <a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026' target="_blank">https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026</a>
#  View run at <a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026/runs/g1yh560v' target="_blank">https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026/runs/g1yh560v</a>
# Epoch 1/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 1.1673131494888112,  F1_score : 0.6219509391222264
# Train Loss: 1.4961
# Epoch 2/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.9957733393223809,  F1_score : 0.6613856424679759
# Train Loss: 1.0618
# Epoch 3/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.9175677251205769,  F1_score : 0.683782993529551
# Train Loss: 0.9461
# Epoch 4/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.873710161460234,  F1_score : 0.6958454895964986
# Train Loss: 0.8873
# Epoch 5/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.8448982752208263,  F1_score : 0.7009258665196773
# Train Loss: 0.8509
# Epoch 6/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.8246305809854698,  F1_score : 0.7095604444625614
# Train Loss: 0.8256
# Epoch 7/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.8091837995087923,  F1_score : 0.7155456198873774
# Train Loss: 0.8068
# Epoch 8/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7948888918357109,  F1_score : 0.7184555843931737
# Train Loss: 0.7924
# Epoch 9/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7892925928650635,  F1_score : 0.7197611016167189
# Train Loss: 0.7804
# Epoch 10/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7758199066749768,  F1_score : 0.7256205383244538
# Train Loss: 0.7705
# Epoch 11/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.770009785699946,  F1_score : 0.7282751014476738
# Train Loss: 0.7627
# Epoch 12/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7671332602689007,  F1_score : 0.7288872828188903
# Train Loss: 0.7554
# Epoch 13/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7576260141599407,  F1_score : 0.7309179692339475
# Train Loss: 0.7491
# Epoch 14/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7543036867814786,  F1_score : 0.7320064693600388
# Train Loss: 0.7439
# Epoch 15/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7481302406106677,  F1_score : 0.7339192594614312
# Train Loss: 0.7388
# Epoch 16/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7464128789235788,  F1_score : 0.7349790590984108
# Train Loss: 0.7345
# Epoch 17/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.741530871213372,  F1_score : 0.7354787547379343
# Train Loss: 0.7307
# Epoch 18/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7389089409857671,  F1_score : 0.7381410239550539
# Train Loss: 0.7269
# Epoch 19/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.735987622346451,  F1_score : 0.7377677525525238
# Train Loss: 0.7237
# Epoch 20/20:   0%|          | 0/1875 [00:00<?, ?it/s]
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7349244298965438,  F1_score : 0.7370005163768364
# Train Loss: 0.7205
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score</td><td>▁▃▅▅▆▆▇▇▇▇▇▇████████</td></tr><tr><td>train_loss</td><td>█▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>f1_score</td><td>0.737</td></tr><tr><td>train_loss</td><td>0.72052</td></tr><tr><td>val_loss</td><td>0.73492</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet-transfer-v1-64-0.0001-1875-20</strong> at: <a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026/runs/g1yh560v' target="_blank">https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026/runs/g1yh560v</a><br> View project at: <a href='https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026' target="_blank">https://wandb.ai/23f1001065-indian-institute-of-technology-madras/23f1001065-t12026</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260313_063856-g1yh560v/logs</code>

# %% [markdown]
# # Validating best model state dict

# %%
b_model = MelResNet18(res_net,10).to(device)
b_model.load_state_dict(best_model_state)
# Out:
# <All keys matched successfully>

# %%
validation(b_model,val_loader,criterion)
# Out:
# Validation:   0%|          | 0/469 [00:00<?, ?it/s]
# 30000 30000
# Validation Loss : 0.7349330136008354,  F1_score : 0.7370005163768364
# ([np.int64(6),
#   np.int64(5),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(6),
#   np.int64(8),
#   np.int64(0),
#   np.int64(3),
#   np.int64(2),
#   np.int64(9),
#   np.int64(4),
#   np.int64(1),
#   np.int64(5),
#   np.int64(8),
#   np.int64(3),
#   np.int64(8),
#   np.int64(3),
#   np.int64(7),
#   np.int64(9),
#   np.int64(6),
#   np.int64(4),
#   np.int64(6),
#   np.int64(0),
#   np.int64(9),
#   np.int64(3),
#   np.int64(6),
#   np.int64(4),
#   np.int64(6),
#   np.int64(4),
#   np.int64(0),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(7),
#   np.int64(0),
#   np.int64(6),
#   np.int64(9),
#   np.int64(8),
#   np.int64(2),
#   np.int64(1),
#   np.int64(8),
#   np.int64(7),
#   np.int64(7),
#   np.int64(5),
#   np.int64(1),
#   np.int64(7),
#   np.int64(3),
#   np.int64(7),
#   np.int64(5),
#   np.int64(7),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(8),
#   np.int64(9),
#   np.int64(9),
#   np.int64(6),
#   np.int64(7),
#   np.int64(8),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(7),
#   np.int64(1),
#   np.int64(4),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1),
#   np.int64(9),
#   np.int64(9),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(2),
#   np.int64(0),
#   np.int64(6),
#   np.int64(5),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(1),
#   np.int64(6),
#   np.int64(6),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64
.int64(3),
#   np.int64(2),
#   np.int64(2),
#   np.int64(4),
#   np.int64(1),
#   np.int64(9),
#   np.int64(1),
#   np.int64(4),
#   np.int64(2),
#   np.int64(9),
#   np.int64(4),
#   np.int64(3),
#   np.int64(3),
#   np.int64(6),
#   np.int64(3),
#   np.int64(2),
#   np.int64(1),
#   np.int64(1),
#   np.int64(5),
#   np.int64(1),
#   np.int64(5),
#   np.int64(7),
#   np.int64(0),
#   np.int64(2),
#   np.int64(4),
#   np.int64(0),
#   np.int64(7),
#   np.int64(3),
#   np.int64(7),
#   np.int64(6),
#   np.int64(5),
#   np.int64(4),
#   np.int64(3),
#   np.int64(8),
#   np.int64(5),
#   np.int64(4),
#   np.int64(0),
#   np.int64(7),
#   np.int64(5),
#   np.int64(2),
#   np.int64(7),
#   np.int64(2),
#   np.int64(1),
#   np.int64(8),
#   np.int64(9),
#   np.int64(2),
#   np.int64(6),
#   np.int64(7),
#   np.int64(1),
#   np.int64(5),
#   np.int64(4),
#   np.int64(3),
#   np.int64(6),
#   np.int64(4),
#   np.int64(2),
#   np.int64(8),
#   np.int64(2),
#   np.int64(0),
#   np.int64(5),
#   np.int64(6),
#   np.int64(7),
#   np.int64(9),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(0),
#   np.int64(9),
#   np.int64(0),
#   np.int64(5),
#   np.int64(4),
#   np.int64(9),
#   np.int64(2),
#   np.int64(6),
#   np.int64(9),
#   np.int64(5),
#   np.int64(1),
#   np.int64(1),
#   np.int64(9),
#   np.int64(8),
#   np.int64(2),
#   np.int64(4),
#   np.int64(5),
#   np.int64(1),
#   np.int64(1),
#   np.int64(6),
#   np.int64(9),
#   np.int64(2),
#   np.int64(1),
#   np.int64(3),
#   np.int64(7),
#   np.int64(2),
#   np.int64(1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(2),
#   np.int64(1),
#   np.int64(7),
#   np.int64(9),
#   np.int64(4),
#   np.int64(9),
#   np.int64(3),
#   np.int64(7),
#   np.int64(6),
#   np.int64(9),
#   np.int64(6),
#   np.int64(8),
#   np.int64(5),
#   np.int64(6),
#   np.int64(8),
#   np.int64(2),
#   np.int64(9),
#   np.int64(0),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(2),
#   np.int64(7),
#   np.int64(3),
#   np.int64(8),
#   np.int64(0),
#   np.int64(8),
#   np.int64(7),
#   np.int64(7),
#   np.int64(8),
#   np.int64(1),
#   np.int64(6),
#   np.int64(3),
#   np.int64(3),
#   np.int64(1),
#   np.int64(7),
#   np.int64(4),
#   np.int64(4),
#   np.int64(4),
#   np.int64(8),
#   np.int64(2),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(7),
#   np.int64(2),
#   np.int64(5),
#   np.int64(8),
#   np.int64(8),
#   np.int64(4),
#   np.int64(3),
#   np.int64(6),
#   np.int64(5),
#   np.int64(7),
#   np.int64(3),
#   np.int64(0),
#   np.int64(6),
#   np.int64(9),
#   np.int64(6),
#   np.int64(9),
#   np.int64(4),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(1),
#   np.int64(1),
#   np.int64(8),
#   np.int64(2),
#   np.int64(2),
#   np.int64(9),
#   np.int64(0),
#   np.int64(2),
#   np.int64(0),
#   np.int64(

#   np.int64(3),
#   np.int64(1),
#   np.int64(1),
#   np.int64(5),
#   np.int64(8),
#   np.int64(4),
#   np.int64(1),
#   np.int64(5),
#   np.int64(8),
#   np.int64(0),
#   np.int64(0),
#   np.int64(7),
#   np.int64(7),
#   np.int64(1),
#   np.int64(4),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(2),
#   np.int64(2),
#   np.int64(6),
#   np.int64(1),
#   np.int64(6),
#   np.int64(3),
#   np.int64(2),
#   np.int64(7),
#   np.int64(3),
#   np.int64(0),
#   np.int64(2),
#   np.int64(3),
#   np.int64(4),
#   np.int64(6),
#   np.int64(9),
#   np.int64(8),
#   np.int64(6),
#   np.int64(8),
#   np.int64(9),
#   np.int64(7),
#   np.int64(7),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(2),
#   np.int64(6),
#   np.int64(8),
#   np.int64(5),
#   np.int64(3),
#   np.int64(9),
#   np.int64(3),
#   np.int64(5),
#   np.int64(5),
#   np.int64(8),
#   np.int64(6),
#   np.int64(7),
#   np.int64(2),
#   np.int64(4),
#   np.int64(8),
#   np.int64(1),
#   np.int64(4),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(4),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(2),
#   np.int64(6),
#   np.int64(9),
#   np.int64(0),
#   np.int64(7),
#   np.int64(3),
#   np.int64(3),
#   np.int64(9),
#   np.int64(0),
#   np.int64(8),
#   np.int64(6),
#   np.int64(0),
#   np.int64(3),
#   np.int64(1),
#   np.int64(9),
#   np.int64(8),
#   np.int64(6),
#   np.int64(1),
#   np.int64(7),
#   np.int64(5),
#   np.int64(4),
#   np.int64(1),
#   np.int64(5),
#   np.int64(3),
#   np.int64(3),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(7),
#   np.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(8),
#   np.int64(0),
#   np.int64(7),
#   np.int64(7),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(3),
#   np.int64(7),
#   np.int64(0),
#   np.int64(2),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(6),
#   np.int64(6),
#   np.int64(6),
#   np.int64(5),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(0),
#   np.int64(8),
#   np.int64(0),
#   np.int64(9),
#   np.int64(4),
#   np.int64(4),
#   np.int64(5),
#   np.int64(8),
#   np.int64(6),
#   np.int64(1),
#   np.int64(8),
#   np.int64(2),
#   np.int64(3),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(2),
#   np.int64(9),
#   np.int64(9),
#   np.int64(7),
#   np.int64(9),
#   np.int64(4),
#   np.int64(6),
#   np.int64(5),
#   np.int64(0),
#   np.int64(2),
#   np.int64(3),
#   np.int64(1),
#   np.int64(3),
#   np.int64(5),
#   np.int64(9),
#   np.int64(7),
#   np.int64(5),
#   np.int64(2),
#   np.int64(5),
#   np.int64(5),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(9),
#   np.int64(4),
#   np.int64(6),
#   np.int64(4),
#   np.int64(3),
#   np.int64(1),
#   np.int64(8),
#   np.int64(5),
#   np.int64(1),
#   np.int64(2),
#   np.int64(3),
#   np.int64(1),
#   np.int64(0),
#   np.int64(3),
#   np.int64(9),
#   np.int64(0),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(1),
#   np.int64(2),
#   np.int64(1),
#   np.int64(0),
#   np.int64(6),
#   np.int64(0),
#   np.int64(6),
#   np.int64(7),
#   np.int64(1),
#   np.int64(5),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(6),
#   np.int64(2),
#   np.int64(5),
#   np.int64(6),
#   np.int64(5),
#   np.int64(7),
#   np.int64(0),
#   np.int64(5),
#   np.int64(4),
#   np.int64(8),
#   np.int64(4),
#   np.int64(2),
#   np.int64(1),
#   np.int64(9),
#   np.int64(1),
#   np.int64(7),
#   np.int64(4),
#   np.int64(4),
#   np.int64(0),
#   np.int64(8),
#   np.int64(1),
#   np.int64(3),
#   np.int64(8),
#   np.int64(9),
#   np.int64(5),
#   np.int64(3),
#   np.int64(2),
#   np.int64(2),
#   ...],
#  [np.int64(6),
#   np.int64(5),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(6),
#   np.int64(8),
#   np.int64(2),
#   np.int64(3),
#   np.int64(2),
#   np.int64(9),
#   np.int64(8),
#   np.int64(1),
#   np.int64(1),
#   np.int64(8),
#   np.int64(3),
#   np.int64(8),
#   np.int64(9),
#   np.int64(7),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(6),
#   np.int64(2),
#   np.int64(9),
#   np.int64(3),
#   np.int64(6),
#   np.int64(8),
#   np.int64(6),
#   np.int64(4),
#   np.int64(0),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(7),
#   np.int64(5),
#   np.int64(6),
#   np.int64(2),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(3),
#   np.int64(7),
#   np.int64(8),
#   np.int64(2),
#   np.int64(1),
#   np.int64(7),
#   np.int64(3),
#   np.int64(7),
#   np.int64(5),
#   np.int64(7),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(8),
#   np.int64(6),
#   np.int64(9),
#   np.int64(6),
#   np.int64(7),
#   np.int64(5),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(7),
#   np.int64(1),
#   np.int64(7),
#   np.int64(1),
#   np.int64(1),
#   np.int64(5),
#   np.int64(2),
#   np.int64(6),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(2),
#   np.int64(0),
#   np.int64(6),
#   np.int64(5),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(1),
#   np.int64(6),
#   np.int64(6),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(8),
#   np.int64(9),
#   np.int64(5),
#   np.int64(8),
#   np.int64(6),
#   np.int64(7),
#   np.int64(4),
#   np.int64(7),
#   np.int64(3),
#   np.int64(2),
#   np.int64(9),
#   np.int64(6),
#   np.int64(3),
#   np.int64(5),
#   np.int64(4),
#   np.int64(8),
#   np.int64(3),
#   np.int64(2),
#   np.int64(3),
#   np.int64(3),
#   np.int64(1),
#   np.int64(2),
#   np.int64(6),
#   np.int64(3),
#   np.int64(4),
#   np.int64(2),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(7),
#   np.int64(1),
#   np.int64(1),
#   np.int64(3),
#   np.int64(9),
#   np.int64(7),
#   np.int64(2),
#   np.int64(0),
#   np.int64(
.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(9),
#   np.int64(5),
#   np.int64(1),
#   np.int64(5),
#   np.int64(4),
#   np.int64(7),
#   np.int64(3),
#   np.int64(7),
#   np.int64(0),
#   np.int64(8),
#   np.int64(4),
#   np.int64(0),
#   np.int64(4),
#   np.int64(5),
#   np.int64(2),
#   np.int64(2),
#   np.int64(5),
#   np.int64(9),
#   np.int64(3),
#   np.int64(0),
#   np.int64(7),
#   np.int64(6),
#   np.int64(9),
#   np.int64(7),
#   np.int64(4),
#   np.int64(9),
#   np.int64(5),
#   np.int64(1),
#   np.int64(7),
#   np.int64(6),
#   np.int64(9),
#   np.int64(4),
#   np.int64(8),
#   np.int64(3),
#   np.int64(2),
#   np.int64(3),
#   np.int64(2),
#   np.int64(8),
#   np.int64(4),
#   np.int64(0),
#   np.int64(0),
#   np.int64(6),
#   np.int64(7),
#   np.int64(7),
#   np.int64(2),
#   np.int64(1),
#   np.int64(3),
#   np.int64(1),
#   np.int64(5),
#   np.int64(3),
#   np.int64(1),
#   np.int64(3),
#   np.int64(9),
#   np.int64(5),
#   np.int64(4),
#   np.int64(8),
#   np.int64(2),
#   np.int64(1),
#   np.int64(4),
#   np.int64(8),
#   np.int64(8),
#   np.int64(1),
#   np.int64(3),
#   np.int64(4),
#   np.int64(8),
#   np.int64(9),
#   np.int64(8),
#   np.int64(7),
#   np.int64(6),
#   np.int64(1),
#   np.int64(6),
#   np.int64(2),
#   np.int64(5),
#   np.int64(3),
#   np.int64(2),
#   np.int64(0),
#   np.int64(4),
#   np.int64(9),
#   np.int64(4),
#   np.int64(7),
#   np.int64(4),
#   np.int64(7),
#   np.int64(5),
#   np.int64(0),
#   np.int64(8),
#   np.int64(8),
#   np.int64(1),
#   np.int64(7),
#   np.int64(9),
#   np.int64(3),
#   np.int64(6),
#   np.int64(6),
#   np.int64(2),
#   np.int64(1),
#   np.int64(1),
#   np.int64(1),
#   np.int64(1),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(6),
#   np.int64(3),
#   np.int64(7),
#   np.int64(6),
#   np.int64(6),
#   np.int64(3),
#   np.int64(2),
#   np.int64(1),
#   np.int64(6),
#   np.int64(4),
#   np.int64(3),
#   np.int64(9),
#   np.int64(6),
#   np.int64(0),
#   np.int64(3),
#   np.int64(2),
#   np.int64(8),
#   np.int64(3),
#   np.int64(4),
#   np.int64(8),
#   np.int64(0),
#   np.int64(3),
#   np.int64(4),
#   np.int64(3),
#   np.int64(6),
#   np.int64(2),
#   np.int64(9),
#   np.int64(8),
#   np.int64(1),
#   np.int64(2),
#   np.int64(7),
#   np.int64(1),
#   np.int64(2),
#   np.int64(3),
#   np.int64(4),
#   np.int64(5),
#   np.int64(3),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(2),
#   np.int64(9),
#   np.int64(6),
#   np.int64(7),
#   np.int64(6),
#   np.int64(8),
#   np.int64(6),
#   np.int64(4),
#   np.int64(2),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(9),
#   np.int64(8),
#   np.int64(3),
#   np.int64(6),
#   np.int64(9),
#   np.int64(8),
#   np.int64(1),
#   np.int64(8),
#   np.int64(3),
#   np.int64(2),
#   np.int64(0),
#   np.int64(4),
#   np.int64(1),
#   np.int64(6),
#   np.int64(1),
#   np.int64(8),
#   np.int64(7),
#   np.int64(9),
#   np.int64(4),
#   np.int64(3),
#   np.int64(3),
#   np.int64(6),
#   np.int64(3),
#   np.int64(2),
#   np.int64(1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(5),
#   np.int64(7),
#   np.int64(0),
#   np.int64(2),
#   np.int64(4),
#   np.int64(8),
#   np.int64(7),
#   np.int64(3),
#   np.int64(7),
#   np.int64(6),
#   np.int64(5),
#   np.int64(4),
#   np.int64(3),
#   np.int64(4),
#   np.int64(0),
#   np.int64(4),
#   np.int64(0),
#   np.int64(7),
#   np.int64(5),
#   np.int64(2),
#   np.int64(7),
#   np.int64(2),
#   np.int64(1),
#   np.int64(8),
#   np.int64(9),
#   np.int64(7),
#   np.int64(6),
#   np.int64(7),
#   np.int64(1),
#   np.int64(2),
#   np.int64(4),
#   np.int64(9),
#   np.int64(6),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(3),
#   np.int64(0),
#   np.int64(5),
#   np.int64(6),
#   np.int64(4),
#   np.int64(9),
#   np.int64(0),
#   np.int64(5),
#   np.int64(3),
#   np.int64(0),
#   np.int64(9),
#   np.int64(0),
#   np.int64(5),
#   np.int64(4),
#   np.int64(3),
#   np.int64(2),
#   np.int64(6),
#   np.int64(9),
#   np.int64(5),
#   np.int64(1),
#   np.int64(1),
#   np.int64(9),
#   np.int64(4),
#   np.int64(2),
#   np.int64(4),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1),
#   np.int64(6),
#   np.int64(8),
#   np.int64(2),
#   np.int64(1),
#   np.int64(0),
#   np.int64(7),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(2),
#   np.int64(1),
#   np.int64(7),
#   np.int64(2),
#   np.int64(4),
#   np.int64(9),
#   np.int64(3),
#   np.int64(7),
#   np.int64(6),
#   np.int64(2),
#   np.int64(6),
#   np.int64(2),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(3),
#   np.int64(9),
#   np.int64(0),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(2),
#   np.int64(7),
#   np.int64(3),
#   np.int64(8),
#   np.int64(0),
#   np.int64(2),
#   np.int64(2),
#   np.int64(7),
#   np.int64(8),
#   np.int64(1),
#   np.int64(9),
#   np.int64(4),
#   np.int64(3),
#   np.int64(1),
#   np.int64(7),
#   np.int64(4),
#   np.int64(7),
#   np.int64(8),
#   np.int64(8),
#   np.int64(2),
#   np.int64(9),
#   np.int64(0),
#   np.int64(3),
#   np.int64(7),
#   np.int64(2),
#   np.int64(5),
#   np.int64(4),
#   np.int64(8),
#   np.int64(8),
#   np.int64(7),
#   np.int64(6),
#   np.int64(5),
#   np.int64(7),
#   np.int64(3),
#   np.int64(2),
#   np.int64(6),
#   np.int64(9),
#   np.int64(6),
#   np.int64(9),
#   np.int64(4),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(1),
#   np.int64(1),
#   np.int64(7),
#   np.int64(5),
#   np.int64(3),
#   np.int64(2),
#   np.int64(0),
#   np.int64(2),
#   np.int64(0),
#   np.int64(3),
#   np.int64(9),
#   np.int64(0),
#   np.int64(4),
#   np.int64(6),
#   np.int64(0),
#   np.int64(6),
#   np.int64(6),
#   np.int64(2),
#   np.int64(1),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(6),
#   np.int64(7),
#   np.int64(7),
#   np.int64(7),
#   np.int64(0),
#   np.int64(8),
#   np.int64(2),
#   np.int64(5),
#   np.int64(8),
#   np.int64(6),
#   np.int64(3),
#   np.int64(6),
#   np.int64(1),
#   np.int64(7),
#   np.int64(3),
#   np.int64(2),
#   np.int64(0),
#   np.int64(1),
#   np.int64(5),
#   np.int64(2),
#   np.int64(5),
#   np.int64(7),
#   np.int64(7),
#   np.int64(1),
#   np.int64(4),
#   np.int64(6),
#   np.int64(3),
#   np.int64(0),
#   np.int64(9),
#   np.int64(3),
#   np.int64(9),
#   np.int64(3),
#   np.int64(1),
#   np.int64(6),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(1),
#   np.int64(8),
#   np.int64(4),
#   np.int64(7),
#   np.int64(9),
#   np.int64(6),
#   np.int64(8),
#   np.int64(4),
#   np.int64(5),
#   np.int64(0),
#   np.int64(4),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(5),
#   np.int64(5),
#   np.int64(7),
#   np.int64(1),
#   np.int64(5),
#   np.int64(3),
#   np.int64(2),
#   np.int64(3),
#   np.int64(0),
#   np.int64(2),
#   np.int64(2),
#   np.int64(8),
#   np.int64(8),
#   np.int64(6),
#   np.int64(6),
#   np.int64(3),
#   np.int64(7),
#   np.int64(3),
#   np.int64(4),
#   np.int64(3),
#   np.int64(1),
#   np.int64(8),
#   np.int64(8),
#   np.int64(1),
#   np.int64(7),
#   np.int64(1),
#   np.int64(1),
#   np.int64(7),
#   np.int64(4),
#   np.int64(2),
#   np.int64(6),
#   np.int64(6),
#   np.int64(4),
#   np.int64(4),
#   np.int64(7),
#   np.int64(2),
#   np.int64(2),
#   np.int64(7),
#   np.int64(1),
#   np.int64(2),
#   np.int64(0),
#   np.int64(9),
#   np.int64(4),
#   np.int64(5),
#   np.int64(9),
#   np.int64(7),
#   np.int64(1),
#   np.int64(5),
#   np.int64(0),
#   np.int64(0),
#   np.int64(7),
#   np.int64(0),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(6),
#   np.int64(2),
#   np.int64(1),
#   np.int64(8),
#   np.int64(0),
#   np.int64(1),
#   np.int64(2),
#   np.int64(4),
#   np.int64(7),
#   np.int64(4),
#   np.int64(0),
#   np.int64(5),
#   np.int64(9),
#   np.int64(3),
#   np.int64(4),
#   np.int64(9),
#   np.int64(8),
#   np.int64(3),
#   np.int64(5),
#   np.int64(5),
#   np.int64(2),
#   np.int64(8),
#   np.int64(4),
#   np.int64(5),
#   np.int64(0),
#   np.int64(2),
#   np.int64(9),
#   np.int64(8),
#   np.int64(4),
#   np.int64(6),
#   np.int64(6),
#   np.int64(7),
#   np.int64(6),
#   np.int64(0),
#   np.int64(7),
#   np.int64(5),
#   np.int64(3),
#   np.int64(9),
#   np.int64(8),
#   np.int64(1),
#   np.int64(5),
#   np.int64(0),
#   np.int64(3),
#   np.int64(1),
#   np.int64(1),
#   np.int64(5),
#   np.int64(4),
#   np.int64(4),
#   np.int64(1),
#   np.int64(5),
#   np.int64(8),
#   np.int64(2),
#   np.int64(0),
#   np.int64(4),
#   np.int64(7),
#   np.int64(1),
#   np.int64(4),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(2),
#   np.int64(8),
#   np.int64(6),
#   np.int64(1),
#   np.int64(6),
#   np.int64(8),
#   np.int64(3),
#   np.int64(7),
#   np.int64(3),
#   np.int64(2),
#   np.int64(2),
#   np.int64(3),
#   np.int64(4),
#   np.int64(6),
#   np.int64(0),
#   np.int64(9),
#   np.int64(6),
#   np.int64(8),
#   np.int64(2),
#   np.int64(7),
#   np.int64(7),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(2),
#   np.int64(6),
#   np.int64(3),
#   np.int64(5),
#   np.int64(3),
#   np.int64(9),
#   np.int64(4),
#   np.int64(5),
#   np.int64(0),
#   np.int64(8),
#   np.int64(6),
#   np.int64(7),
#   np.int64(2),
#   np.int64(4),
#   np.int64(7),
#   np.int64(1),
#   np.int64(8),
#   np.int64(0),
#   np.int64(6),
#   np.int64(4),
#   np.int64(4),
#   np.int64(9),
#   np.int64(1),
#   np.int64(3),
#   np.int64(0),
#   np.int64(6),
#   np.int64(2),
#   np.int64(0),
#   np.int64(7),
#   np.int64(3),
#   np.int64(2),
#   np.int64(2),
#   np.int64(0),
#   np.int64(8),
#   np.int64(6),
#   np.int64(0),
#   np.int64(3),
#   np.int64(1),
#   np.int64(9),
#   np.int64(8),
#   np.int64(6),
#   np.int64(1),
#   np.int64(7),
#   np.int64(5),
#   np.int64(4),
#   np.int64(1),
#   np.int64(5),
#   np.int64(4),
#   np.int64(3),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(9),
#   np.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(7),
#   np.int64(3),
#   np.int64(8),
#   np.int64(3),
#   np.int64(8),
#   np.int64(7),
#   np.int64(1),
#   np.int64(4),
#   np.int64(7),
#   np.int64(0),
#   np.int64(2),
#   np.int64(6),
#   np.int64(1),
#   np.int64(0),
#   np.int64(6),
#   np.int64(6),
#   np.int64(6),
#   np.int64(5),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(6),
#   np.int64(8),
#   np.int64(4),
#   np.int64(9),
#   np.int64(4),
#   np.int64(4),
#   np.int64(0),
#   np.int64(8),
#   np.int64(6),
#   np.int64(1),
#   np.int64(8),
#   np.int64(2),
#   np.int64(8),
#   np.int64(4),
#   np.int64(9),
#   np.int64(1),
#   np.int64(2),
#   np.int64(5),
#   np.int64(9),
#   np.int64(7),
#   np.int64(6),
#   np.int64(4),
#   np.int64(6),
#   np.int64(5),
#   np.int64(0),
#   np.int64(2),
#   np.int64(3),
#   np.int64(1),
#   np.int64(8),
#   np.int64(5),
#   np.int64(6),
#   np.int64(7),
#   np.int64(5),
#   np.int64(2),
#   np.int64(5),
#   np.int64(5),
#   np.int64(6),
#   np.int64(5),
#   np.int64(3),
#   np.int64(9),
#   np.int64(4),
#   np.int64(6),
#   np.int64(4),
#   np.int64(3),
#   np.int64(1),
#   np.int64(7),
#   np.int64(5),
#   np.int64(1),
#   np.int64(2),
#   np.int64(7),
#   np.int64(1),
#   np.int64(0),
#   np.int64(3),
#   np.int64(0),
#   np.int64(0),
#   np.int64(5),
#   np.int64(3),
#   np.int64(8),
#   np.int64(1),
#   np.int64(2),
#   np.int64(5),
#   np.int64(8),
#   np.int64(6),
#   np.int64(0),
#   np.int64(6),
#   np.int64(2),
#   np.int64(1),
#   np.int64(5),
#   np.int64(6),
#   np.int64(1),
#   np.int64(2),
#   np.int64(6),
#   np.int64(8),
#   np.int64(5),
#   np.int64(6),
#   np.int64(5),
#   np.int64(7),
#   np.int64(0),
#   np.int64(5),
#   np.int64(4),
#   np.int64(7),
#   np.int64(4),
#   np.int64(6),
#   np.int64(1),
#   np.int64(9),
#   np.int64(1),
#   np.int64(7),
#   np.int64(8),
#   np.int64(3),
#   np.int64(0),
#   np.int64(8),
#   np.int64(1),
#   np.int64(9),
#   np.int64(8),
#   np.int64(2),
#   np.int64(5),
#   np.int64(3),
#   np.int64(2),
#   np.int64(2),
#   ...],
#  0.7370005163768364,
#  0.7349330136008354)

# %% [markdown]
# # Saving model

# %%
model_name = config['model_name']
if os.path.exists(f"/kaggle/working/{model_name}"):
    checkpoint={
        'run_name' : run_name,
        'epoch' : config['epochs'],
        'train_loss' : train_loss,
        'val_loss' : val_loss,
        'f1_score' : f1,
        'model_state_dict' : best_model_state,
        'optimizer_state_dict' : best_optim_state
    }
    torch.save(checkpoint, f"/kaggle/working/{model_name}/checkpoint.pth")
    print(f"✅ {model_name} saved.")
else:
    print(f"Path not exists.")
# Out:
# ✅ resnet-transfer saved.

# %% [markdown]
# # Uploading to KaggleHub

# %%
import kagglehub

# Replace with path to directory containing model files.
model_name = config['model_name']
LOCAL_MODEL_DIR = f'/kaggle/working/{model_name}'

MODEL_SLUG = model_name # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = 'default' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"akashkumbhakar/{MODEL_SLUG}/pyTorch/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = '')
# Out:
# Uploading Model https://api.kaggle.com/models/akashkumbhakar/resnet-transfer/pyTorch/default ...
# Model 'resnet-transfer' does not exist or access is forbidden for user 'akashkumbhakar'. Creating or handling Model...
# Model 'resnet-transfer' Created.
# Starting upload for file /kaggle/working/resnet-transfer/checkpoint.pth
# Uploading: 100%|██████████| 44.8M/44.8M [00:01<00:00, 44.6MB/s]
# Upload successful: /kaggle/working/resnet-transfer/checkpoint.pth (43MB)
# Your model instance has been created.
# Files are being processed...
# See at: https://api.kaggle.com/models/akashkumbhakar/resnet-transfer/pyTorch/default
